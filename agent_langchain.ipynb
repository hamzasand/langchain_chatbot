# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
GOOGLE_API_KEY= os.getenv("GOOGLE_API_KEY")
LANGCHAIN_TRACING_V2= os.getenv("LANGCHAIN_TRACING_V2")
LANGCAHIN_API_KEY= os.getenv("LANGCAHIN_API_KEY")
TAVILY_API_KEY= os.getev("TAVILY_API_KEY")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 4
#       1 GOOGLE_API_KEY= os.getenv("GOOGLE_API_KEY")
#       2 LANGCHAIN_TRACING_V2= os.getenv("LANGCHAIN_TRACING_V2")
#       3 LANGCAHIN_API_KEY= os.getenv("LANGCAHIN_API_KEY")
# ----> 4 TAVILY_API_KEY= os.get("TAVILY_API_KEY")
#
# AttributeError: module 'os' has no attribute 'get'
